# %% [markdown]
# # Preparación de datasets

# %%
# importacion general de librerias
import pandas as pd

pd.options.display.float_format = '{:20,.2f}'.format # suprimimos la notacion cientifica en los outputs

import warnings
warnings.filterwarnings('ignore')

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
#https://drive.google.com/file/d/1y4_n4twjE4VSLSC-V7QsdPJ5JR9fiVgG/view?usp=sharing GooglePlayStore.csv

id='1y4_n4twjE4VSLSC-V7QsdPJ5JR9fiVgG'
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('GooglePlayStore.csv')

# %% [markdown]
# Se obtuvieron únicamente las columnas necesarias para la resolución de los problemas en cuestión.

# %%
appDetails=pd.read_csv('GooglePlayStore.csv', usecols=['App','Rating','Reviews','Current Ver'])

# %%
appDetails
# Out:
#                                                      App               Rating  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook                 4.10
# 1                                    Coloring book moana                 3.90
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...                 4.70
# 3                                  Sketch - Draw & Paint                 4.50
# 4                  Pixel Draw - Number Art Coloring Book                 4.30
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR                 4.50
# 10837                   Fr. Mike Schmitz Audio Teachings                 5.00
# 10838                             Parkinson Exercices FR                  NaN
# 10839                      The SCP Foundation DB fr nn5n                 4.50
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology                 4.50
#
#       Reviews         Current Ver
# 0         159               1.0.0
# 1         967               2.0.0
# 2       87510               1.2.4
# 3      215644  Varies with device
# 4         967                 1.1
# ...       ...                 ...
# 10836      38                1.48
# 10837       4                 1.0
# 10838       3                 1.0
# 10839     114  Varies with device
# 10840  398307  Varies with device
#
# [10841 rows x 4 columns]

# %%
appDetails.duplicated().value_counts()
# Out:
# False    10350
# True       491
# dtype: int64

# %% [markdown]
# Se droppearon las aplicaciones con el mismo valor en todas las columnas, dado que podrían existir aplicaciones con el mismo nombre.

# %%
validAppDetails = appDetails.drop_duplicates()
validAppDetails
# Out:
#                                                      App               Rating  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook                 4.10
# 1                                    Coloring book moana                 3.90
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...                 4.70
# 3                                  Sketch - Draw & Paint                 4.50
# 4                  Pixel Draw - Number Art Coloring Book                 4.30
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR                 4.50
# 10837                   Fr. Mike Schmitz Audio Teachings                 5.00
# 10838                             Parkinson Exercices FR                  NaN
# 10839                      The SCP Foundation DB fr nn5n                 4.50
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology                 4.50
#
#       Reviews         Current Ver
# 0         159               1.0.0
# 1         967               2.0.0
# 2       87510               1.2.4
# 3      215644  Varies with device
# 4         967                 1.1
# ...       ...                 ...
# 10836      38                1.48
# 10837       4                 1.0
# 10838       3                 1.0
# 10839     114  Varies with device
# 10840  398307  Varies with device
#
# [10350 rows x 4 columns]

# %% [markdown]
# Las aplicaciones sin nombre no son válidas:

# %%
validAppDetails = validAppDetails[appDetails['App'].notna()]
validAppDetails
# Out:
#                                                      App               Rating  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook                 4.10
# 1                                    Coloring book moana                 3.90
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...                 4.70
# 3                                  Sketch - Draw & Paint                 4.50
# 4                  Pixel Draw - Number Art Coloring Book                 4.30
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR                 4.50
# 10837                   Fr. Mike Schmitz Audio Teachings                 5.00
# 10838                             Parkinson Exercices FR                  NaN
# 10839                      The SCP Foundation DB fr nn5n                 4.50
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology                 4.50
#
#       Reviews         Current Ver
# 0         159               1.0.0
# 1         967               2.0.0
# 2       87510               1.2.4
# 3      215644  Varies with device
# 4         967                 1.1
# ...       ...                 ...
# 10836      38                1.48
# 10837       4                 1.0
# 10838       3                 1.0
# 10839     114  Varies with device
# 10840  398307  Varies with device
#
# [10350 rows x 4 columns]

# %%
validAppDetails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10350 entries, 0 to 10840
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   App          10350 non-null  object
#  1   Rating       8885 non-null   float64
#  2   Reviews      10350 non-null  object
#  3   Current Ver  10342 non-null  object
# dtypes: float64(1), object(3)
# memory usage: 404.3+ KB

# %%
validAppDetails[validAppDetails['Rating']>5]
# Out:
#                                            App               Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame                19.00    3.0M
#
#       Current Ver
# 10472  4.0 and up

# %%
validAppDetails = validAppDetails.drop(10472)
validAppDetails
# Out:
#                                                      App               Rating  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook                 4.10
# 1                                    Coloring book moana                 3.90
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...                 4.70
# 3                                  Sketch - Draw & Paint                 4.50
# 4                  Pixel Draw - Number Art Coloring Book                 4.30
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR                 4.50
# 10837                   Fr. Mike Schmitz Audio Teachings                 5.00
# 10838                             Parkinson Exercices FR                  NaN
# 10839                      The SCP Foundation DB fr nn5n                 4.50
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology                 4.50
#
#       Reviews         Current Ver
# 0         159               1.0.0
# 1         967               2.0.0
# 2       87510               1.2.4
# 3      215644  Varies with device
# 4         967                 1.1
# ...       ...                 ...
# 10836      38                1.48
# 10837       4                 1.0
# 10838       3                 1.0
# 10839     114  Varies with device
# 10840  398307  Varies with device
#
# [10349 rows x 4 columns]

# %% [markdown]
# Cambiamos el datatype de algunas columnas para mejorar el rendimiento.

# %%
validAppDetails['App']=validAppDetails['App'].astype('string')
validAppDetails['Rating']=validAppDetails['Rating'].astype('float')
validAppDetails['Reviews']=validAppDetails['Reviews'].astype('int')
validAppDetails.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10349 entries, 0 to 10840
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   App          10349 non-null  string
#  1   Rating       8884 non-null   float64
#  2   Reviews      10349 non-null  int64
#  3   Current Ver  10341 non-null  object
# dtypes: float64(1), int64(1), object(1), string(1)
# memory usage: 404.3+ KB

# %% [markdown]
# # Ejercicio 15
# Para aquellas aplicaciones que se encuentren en su versión 1.0 (o 1.0.0) y que tengan más de 50000 reviews. ¿Cuál es el top 5 con mejor rating? (⭐)

# %%
ver1AppDetails = validAppDetails[validAppDetails['Current Ver'].isin(['1.0','1.0.0'])]
ver1AppDetails
# Out:
#                                                   App               Rating  \
# 0      Photo Editor & Candy Camera & Grid & ScrapBook                 4.10
# 5                          Paper flowers instructions                 4.40
# 17                           350 Diy Room Decor Ideas                 4.50
# 23                             Mcqueen Coloring pages                  NaN
# 29                    Easy Realistic Drawing Tutorial                 4.10
# ...                                               ...                  ...
# 10823                                    List iptv FR                  NaN
# 10825                              Naruto & Boruto FR                  NaN
# 10834                                   FR Calculator                 4.00
# 10837                Fr. Mike Schmitz Audio Teachings                 5.00
# 10838                          Parkinson Exercices FR                  NaN
#
#        Reviews Current Ver
# 0          159       1.0.0
# 5          167         1.0
# 17          27         1.0
# 23          61       1.0.0
# 29         223         1.0
# ...        ...         ...
# 10823        1         1.0
# 10825        7         1.0
# 10834        7       1.0.0
# 10837        4         1.0
# 10838        3         1.0
#
# [937 rows x 4 columns]

# %%
ver1Reviews50000AppDetails = ver1AppDetails[ver1AppDetails['Reviews']>50000]
ver1Reviews50000AppDetails
# Out:
#                                      App               Rating  Reviews  \
# 1523          Aviary Stickers: Free Pack                 3.50   126862
# 2012                     Racing in Car 2                 4.30   234110
# 2231          My Little Pony Celebration                 4.30    63160
# 4758                      iSwipe Phone X                 4.70    58366
# 5422          High School Simulator 2017                 4.20   123136
# 5423   Hopeless Land: Fight for Survival                 4.20   250197
# 7604      StirFry Stunts - We Bare Bears                 4.50   121533
# 8309                     Racing in Car 2                 4.30   234589
# 9343          My Little Pony Celebration                 4.30    63192
# 10211                          Messenger                 4.10    68025
#
#       Current Ver
# 1523          1.0
# 2012          1.0
# 2231        1.0.0
# 4758          1.0
# 5422          1.0
# 5423          1.0
# 7604        1.0.0
# 8309          1.0
# 9343        1.0.0
# 10211         1.0

# %% [markdown]
# El top 5 con mejor rating entre las aplicaciones de versión 1.0 (o 1.0.0) con más de 50000 reviews:

# %%
ver1Reviews50000AppDetails.sort_values(['Rating'], ascending=False).head(5)
# Out:
#                                  App               Rating  Reviews Current Ver
# 4758                  iSwipe Phone X                 4.70    58366         1.0
# 7604  StirFry Stunts - We Bare Bears                 4.50   121533       1.0.0
# 2012                 Racing in Car 2                 4.30   234110         1.0
# 2231      My Little Pony Celebration                 4.30    63160       1.0.0
# 8309                 Racing in Car 2                 4.30   234589         1.0
